# %% [markdown]
# # Attention Lineplot
#
# Render the per-head last-block attention distribution grid.

# %%
from pathlib import Path
import sys

_UTIL_DIR = Path("notebooks/26Mar26-PyramidForcing-frames72")
if _UTIL_DIR.exists():
    sys.path.insert(0, str(_UTIL_DIR.resolve()))

# %% [markdown]
# ## Parameters

# %%
DATA_PATH = "../../data/26Mar26-PyramidForcing-frames72/layer0.pt"
SAVE_DIR = "../../figures/26Mar26-PyramidForcing-Frames72/layer0"
SAVE_SVG = True

BAR_COLOR = "tab:blue"

# %% [markdown]
# ## Render

# %%
from attention_plot_utils import render_attention_lineplots

render_attention_lineplots(
    DATA_PATH,
    SAVE_DIR,
    bar_color=BAR_COLOR,
    save_svg=SAVE_SVG,
)
# Out:
# ...
# Layer: 0
# Prompt: A majestic eagle soaring through a cloudy sky, cinematic lighting
# Num frames: 72
# Num heads: 12
# Block sizes: [3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3]
# Last block Q frames: [69, 70, 71]
#
# Full attention shape: (12, 72, 72)
# Range: [-6.3047, 11.1406]
#
# Last block attention shape: (12, 72)
# Saved: /home/winbeau/Tools/jupyter-plot/figures/26Mar26-PyramidForcing-Frames72/layer0/layer0_perhead_grid.svg
# {'svg': PosixPath('/home/winbeau/Tools/jupyter-plot/figures/26Mar26-PyramidForcing-Frames72/layer0/layer0_perhead_grid.svg')}
