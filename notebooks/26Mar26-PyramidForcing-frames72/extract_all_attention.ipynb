# %% [markdown]
# # Single-Layer Attention Report
#
# Compatibility entry point that renders both attention heatmaps and per-head distribution plots.

# %%
# %load_ext autoreload
# %autoreload 2

from pathlib import Path
import sys

_UTIL_DIR = Path("notebooks/26Mar26-PyramidForcing-frames72")
if _UTIL_DIR.exists():
    sys.path.insert(0, str(_UTIL_DIR.resolve()))

# %% [markdown]
# ## Parameters

# %%
DATA_PATH = "../../data/26Mar26-PyramidForcing-frames72/layer8.pt"
SAVE_DIR = "../../figures/26Mar26-PyramidForcing-Frames72/"
SAVE_SVG = True

FIGSIZE = (5.81, 4.2)
CMAP = "RdBu_r"
TICK_POSITIONS = [0, 36, 71]
COLOR_MIN = -24
COLOR_MAX = 18.0
SAVE_PDF = True
SAVE_PNG = True
BAR_COLOR = "tab:blue"

# %% [markdown]
# ## Render

# %%
from attention_plot_utils import render_attention_report

render_attention_report(
    DATA_PATH,
    SAVE_DIR,
    figsize=FIGSIZE,
    cmap=CMAP,
    tick_positions=TICK_POSITIONS,
    color_min=COLOR_MIN,
    color_max=COLOR_MAX,
    save_pdf=SAVE_PDF,
    save_png=SAVE_PNG,
    save_svg=SAVE_SVG,
    bar_color=BAR_COLOR,
)
# Out:
# ...
# Layer: 8
# Prompt: A majestic eagle soaring through a cloudy sky, cinematic lighting
# Num frames: 72
# Num heads: 12
# Block sizes: [3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3]
# Last block Q frames: [69, 70, 71]
#
# Full attention shape: (12, 72, 72)
# Range: [-18.2344, 10.3828]
#
# Last block attention shape: (12, 72)
# Saved PDF: /home/winbeau/Tools/jupyter-plot/figures/26Mar26-PyramidForcing-Frames72/layer8_2d_heatmap_all_heads.pdf
# Saved PNG: /home/winbeau/Tools/jupyter-plot/figures/26Mar26-PyramidForcing-Frames72/layer8_2d_heatmap_all_heads.png
# Saved SVG: /home/winbeau/Tools/jupyter-plot/figures/26Mar26-PyramidForcing-Frames72/layer8_2d_heatmap_all_heads.svg
# Fixed range: [-24.000, 0.000, 18.000]
# Saved: /home/winbeau/Tools/jupyter-plot/figures/26Mar26-PyramidForcing-Frames72/layer8_perhead_grid.svg
# Saved PDF: /home/winbeau/Tools/jupyter-plot/figures/26Mar26-PyramidForcing-Frames72/layer8_attention_heatmap_lineplot_row.pdf
# ...
